# %% [markdown]
# <center>
#     <img src="https://s3-api.us-geo.objectstorage.softlayer.net/cf-courses-data/CognitiveClass/Logos/organization_logo/organization_logo.png" width="300" alt="cognitiveclass.ai logo"  />
# </center>

# %% [markdown]
# #### Add your code below following the instructions given in the course

# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# **Estella Chan**
#
# Student

# %% [markdown]
# I am interested in data science because it has many possibilies with its application.

# %% [markdown]
# ### Say hello to you!

# %%
# with string
for i in 'HELLO':
    print(i)
# Out:
# H
# E
# L
# L
# O

# %% [markdown]
# ![1200px-Cat_using_computer.jpg](attachment:1200px-Cat_using_computer.jpg)
#
# https://en.uncyclopedia.co/wiki/A_Cat_on_a_Laptop
#
# >Keep it up!☺
